# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
im = plt.imread(r'section 2\images\rosa.jpg')

# %%
im3 = im.copy()

# %%
im3[140:190,339:405]= 255 # left eye

# %%
im3[136:186,460:530]= 255 #right eye

# %%
plt.imshow(im3,cmap='gray')

# %%
! pip install opencv-contrib-python
# Out:
# Requirement already satisfied: opencv-contrib-python in c:\users\shark\anaconda3\lib\site-packages (4.7.0.72)
# Requirement already satisfied: numpy>=1.19.3 in c:\users\shark\anaconda3\lib\site-packages (from opencv-contrib-python) (1.21.5)

# %% [markdown]
# # Grayscale Images in OpenCV

# %%
import cv2

# %%
img = cv2.imread(r'section 2\images\rosa.jpg',cv2.IMREAD_GRAYSCALE)

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.dtype
# Out:
# dtype('uint8')

# %%
img.shape
# Out:
# (613, 920)

# %%
plt.imshow(img,cmap='gray') # using plt

# %%
Cv2.imshow('GRAY',img) 
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1136\988661800.py in <module>
# ----> 1 Cv2.imshow('GRAY',img)
#       2 cv2.waitKey(0)
#       3 cv2.destroyAllWindows()
#
# NameError: name 'Cv2' is not defined
