# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
im = plt.imread(r'section 2\images\rosa.jpg')

# %%
im3 = im.copy()

# %%
im3[140:190,339:405]= 255 # left eye

# %%
im3[136:186,460:530]= 255 #right eye

# %%
plt.imshow(im3,cmap='gray')

# %%
! pip install opencv-contrib-python
# Out:
# Requirement already satisfied: opencv-contrib-python in c:\users\shark\anaconda3\envs\cv\lib\site-packages (4.7.0.72)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\shark\anaconda3\envs\cv\lib\site-packages (from opencv-contrib-python) (1.21.5)

# %% [markdown]
# # Grayscale Images in OpenCV

# %%
import cv2

# %%
img = cv2.imread(r'section 2\images\rosa.jpg',cv2.IMREAD_GRAYSCALE)

# %%
#img = cv2.imread(r'section 2\images\rosa.jpg',cv2.IMREAD_GRAYSCALE)

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.dtype
# Out:
# dtype('uint8')

# %%
img.shape
# Out:
# (613, 920)

# %%
img[23,100]=200

# %%
#plt.imshow(img,cmap='gray') # using plt

# %%
#using open cv to view image in separate window

# %%
cv2.imshow('Gray',img) 
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img[500:700,500:600] = 255

# %%
#showing white patach

# %%
#save image
cv2.imwrite(r'section 2\images\rosa_white_opencv.jpg',img)
# Out:
# True
